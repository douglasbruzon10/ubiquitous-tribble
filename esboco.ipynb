# %% [markdown]
# # Automatizando tarefas com Python

# %% [markdown]
# - Passo 1: buscar dados dos valores das ações de forma automática no site do yahoo Finanças.
# - Passo 2 : gerar as análises solicitadas pelo gestor de forma automática .
# - Passo 3 : enviar um email automaticamente para o gestor com os resultados das análises.

# %% [markdown]
# # Passo 1

# %%
# !pip install yfinance
# !pip install matplotlib
# Out:
# Requirement already satisfied: yfinance in c:\python311\lib\site-packages (0.2.23)
# Requirement already satisfied: pandas>=1.3.0 in c:\python311\lib\site-packages (from yfinance) (2.0.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\python311\lib\site-packages (from yfinance) (1.24.2)
# Requirement already satisfied: requests>=2.26 in c:\python311\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\python311\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\python311\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\python311\lib\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\python311\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\python311\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\python311\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: six>=1.9 in c:\users\douglas\appdata\roaming\python\python311\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\python311\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\douglas\appdata\roaming\python\python311\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests>=2.26->yfinance) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests>=2.26->yfinance) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests>=2.26->yfinance) (2023.5.7)
# Requirement already satisfied: matplotlib in c:\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\python311\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\douglas\appdata\roaming\python\python311\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python311\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\douglas\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\douglas\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import yfinance
import matplotlib

# %%
ticker = input("Digite a sigla da ação desejada: ")
dados = yfinance.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Passo 2
# Análise dos últimos 6 meses:
# - Cotação máxima
# - Cotação mínima
# - Cotação atual

# %%
minima = fechamento.min()
maxima = fechamento.max()
atual = fechamento[-1]

# %% [markdown]
# # Passo 3
# - abir uma nova aba e digitar o endereço de email
# - clicar no botão escrever email
# - preencher o email do destinatário
# - preencher o assunto
# - escrever o email
# - clicar em enviar

# %%
# !pip install pyautogui
# !pip install pyperclip
# Out:
# Requirement already satisfied: pyautogui in c:\python311\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\python311\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\python311\lib\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\python311\lib\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\python311\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\python311\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\python311\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyscreenshot in c:\python311\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: Pillow>=9.3.0 in c:\python311\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.5.0)
# Requirement already satisfied: pyperclip in c:\python311\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: EasyProcess in c:\python311\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: entrypoint2 in c:\python311\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: mss in c:\python311\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: pyperclip in c:\python311\lib\site-packages (1.8.2)

# %%
import pyautogui

# %%
import pyperclip

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
pyautogui.PAUSE = 2
browser = webdriver.Chrome()
browser.maximize_window()
browser.get('http://www.gmail.com')
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("enter")
pyautogui.click(x=170, y=302)

pyperclip.copy("douglasbruzon10@gmail.com")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

mensagem = f""" Prezado Gestor 
 Segue as análises dos últimos seis meses da ação {ticker}:
 Cotação máxima: R${round(maxima, 2)}
 Cotação mínima: R${round(minima, 2)}
 Cotação atual : R${round(atual, 2)}

Qualquer dúvida estou à disposição!

Att,
 """
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl","v")
pyautogui.click(x=1146, y=1036)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 29
#      27 pyperclip.copy(mensagem)
#      28 pyautogui.hotkey("ctrl","v")
# ---> 29 pyautogui.click(x=1146, y=1036)
#
# File c:\Python311\Lib\site-packages\pyautogui\__init__.py:595, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     593 failSafeCheck()
#     594 returnVal = wrappedFunction(*args, **kwargs)
# --> 595 _handlePause(kwargs.get("_pause", True))
#     596 return returnVal
#
# File c:\Python311\Lib\site-packages\pyautogui\__init__.py:639, in _handlePause(_pause)
#     637 if _pause:
#     638     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 639     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %%
import time

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1146, y=1036)
